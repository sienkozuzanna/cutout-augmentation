# %%
from sklearn.model_selection import train_test_split

import torch
import torch.nn.functional as F
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
import torchvision
from torchvision import transforms as T
import tensorflow as tf
import matplotlib.pyplot as plt
import random
import os
from tensorflow.keras.utils import to_categorical
import numpy as np
from sklearn.metrics import classification_report,  confusion_matrix, ConfusionMatrixDisplay

from augmentation_generator_batch_size import *
from custom_transformers import *

# %%
def seed_everything(seed: int=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


seed_everything(51)

# %% [markdown]
# ## Load data

# %%
cifar10 = tf.keras.datasets.cifar10

(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
print(f"X_train.shape: {X_train.shape} \nY_train.shape: {Y_train.shape} \nX_test.shape: {X_test.shape} \nY_test.shape: {Y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# X_train.shape: (50000, 32, 32, 3)
# Y_train.shape: (50000, 1)
# X_test.shape: (10000, 32, 32, 3)
# Y_test.shape: (10000, 1)

# %% [markdown]
# ## Random Pixels Cutout - without soft labeling

# %%
pixel_cutout = RandomPixelCutout(max_cutout_size=0.1, color=False)
generator = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=32, shuffle=True, augmentor= pixel_cutout, augment_fraction=0.2, overwrite=False, soft_label=False)

batch_x, batch_y = generator[0]

def denormalize(x):
    x = x.copy()
    x = np.clip(x * 255.0, 0, 255)
    return x.astype(np.uint8)

n = len(batch_x)
cols = 4
rows = n//cols + int(n%cols != 0)

fig, axes = plt.subplots(rows, cols, figsize=(18, 12))
if rows == 1 or cols == 1:
    axes = np.expand_dims(axes, axis=0)
for i in range(len(batch_x)):
    row = i // cols
    col = i % cols
    ax = axes[row, col]
    ax.imshow(denormalize(batch_x[i]))
    ax.set_title(batch_y[i], fontsize=8)
    ax.axis('off')

# %% [markdown]
# ## CNN : max pixels size = 10%
# Without soft labels

# %%
pixel_cutout = RandomPixelCutout(max_cutout_size=0.1, color=False)


train_generator = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=32, shuffle=True, augmentor=pixel_cutout, augment_fraction=0.2, num_classes=10, overwrite=False, soft_label=False)
test_generator = AugmentedCIFAR10Generator(X_test, Y_test, batch_size=32, augmentor=None, shuffle=False)

# %%
k = 10
i = Input(shape=X_train[0].shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.25)(x)

#hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)

#last hidden layer i.e.. output layer
x = Dense(k, activation='softmax')(x)

model = Model(i, x)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(
 train_generator, validation_data = test_generator, epochs=6)
# Out:
# Epoch 1/6
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 8ms/step - accuracy: 0.4355 - loss: 1.7359 - val_accuracy: 0.6334 - val_loss: 1.0564
# Epoch 2/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.6829 - loss: 0.9019 - val_accuracy: 0.6889 - val_loss: 0.9506
# Epoch 3/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.7583 - loss: 0.6964 - val_accuracy: 0.7279 - val_loss: 0.8271
# Epoch 4/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8041 - loss: 0.5710 - val_accuracy: 0.7758 - val_loss: 0.6663
# Epoch 5/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8395 - loss: 0.4703 - val_accuracy: 0.7859 - val_loss: 0.6460
# Epoch 6/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8686 - loss: 0.3752 - val_accuracy: 0.8010 - val_loss: 0.6241

# %% [markdown]
# ## Model statistics

# %%
y_pred = model.predict(test_generator, steps=len(test_generator), verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)

y_true = np.argmax(test_generator.y_combined, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %% [markdown]
# Classification report

# %%
print(classification_report(y_true, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.78      0.83      1000
#            1       0.89      0.94      0.91      1000
#            2       0.70      0.72      0.71      1000
#            3       0.58      0.70      0.64      1000
#            4       0.82      0.71      0.76      1000
#            5       0.75      0.71      0.73      1000
#            6       0.76      0.91      0.83      1000
#            7       0.90      0.81      0.86      1000
#            8       0.92      0.86      0.89      1000
#            9       0.88      0.87      0.87      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.81      0.80      0.80     10000
# weighted avg       0.81      0.80      0.80     10000

# %% [markdown]
# Confusion matrix

# %%
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Accuracy

# %%
print(f"Final Training Accuracy: {r.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {r.history['val_accuracy'][-1]:.4f}")
plt.plot(r.history['accuracy'], label='Train Accuracy', color = '#4ea2d3')
plt.plot(r.history['val_accuracy'], label='Validation Accuracy', color = '#ce1ddd')
plt.title("Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
epochs = len(r.history['accuracy'])
plt.xticks(ticks=range(epochs))
plt.grid(True)
plt.show()
# Out:
# Final Training Accuracy: 0.8619
# Final Validation Accuracy: 0.8010

# %% [markdown]
# Final Val Acc : 0.8 </br>
# Final Train Acc : 0.86

# %%
model.save('random_pixels_10.keras')

# %% [markdown]
# ## CNN : max pixel size 5%
# without soft labels

# %%
random_pixels_5 = RandomPixelCutout(max_cutout_size=0.05, color=False)
train_generator = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=32, shuffle=True, augmentor=random_pixels_5, augment_fraction=0.2, num_classes=10, overwrite=False, soft_label=False)
test_generator = AugmentedCIFAR10Generator(X_test, Y_test, batch_size=32, augmentor=None, shuffle=False)

# %%
k = 10
i = Input(shape=X_train[0].shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.25)(x)

#hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)

#last hidden layer i.e.. output layer
x = Dense(k, activation='softmax')(x)

model = Model(i, x)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(
 train_generator, validation_data = test_generator, epochs=6)
# Out:
# Epoch 1/6
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - accuracy: 0.4456 - loss: 1.7074 - val_accuracy: 0.6552 - val_loss: 0.9784
# Epoch 2/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.6974 - loss: 0.8737 - val_accuracy: 0.6512 - val_loss: 1.0415
# Epoch 3/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.7641 - loss: 0.6862 - val_accuracy: 0.7638 - val_loss: 0.6826
# Epoch 4/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8102 - loss: 0.5550 - val_accuracy: 0.7565 - val_loss: 0.7259
# Epoch 5/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.8441 - loss: 0.4515 - val_accuracy: 0.7924 - val_loss: 0.6334
# Epoch 6/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8696 - loss: 0.3777 - val_accuracy: 0.8123 - val_loss: 0.5751

# %% [markdown]
# ## Model statistics pixels = 5%

# %%
y_pred = model.predict(test_generator, steps=len(test_generator), verbose = 1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_generator.y_combined, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
print(classification_report(y_pred_classes, y_true))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.84       986
#            1       0.90      0.92      0.91       981
#            2       0.68      0.81      0.74       846
#            3       0.72      0.60      0.65      1201
#            4       0.79      0.80      0.79       984
#            5       0.71      0.73      0.72       971
#            6       0.83      0.87      0.85       946
#            7       0.88      0.83      0.85      1067
#            8       0.91      0.88      0.89      1034
#            9       0.87      0.89      0.88       984
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.82      0.81     10000
# weighted avg       0.81      0.81      0.81     10000

# %%
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
print(f"Final Training Accuracy: {r.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {r.history['val_accuracy'][-1]:.4f}")
plt.plot(r.history['accuracy'], label='Train Accuracy', color = '#4ea2d3')
plt.plot(r.history['val_accuracy'], label='Validation Accuracy', color = '#ce1ddd')
plt.title("Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
epochs = len(r.history['accuracy'])
plt.xticks(ticks=range(epochs))
plt.grid(True)
plt.show()
# Out:
# Final Training Accuracy: 0.8656
# Final Validation Accuracy: 0.8123

# %% [markdown]
# Final Val Acc : 0.81 </br>
# Final Train Acc : 0.87

# %%
model.save('random_pixels_5.keras')

# %% [markdown]
# ## CNN : max pixel size 5%
# with soft labels

# %%
random_pixels_5 = RandomPixelCutout(max_cutout_size=0.05, color=False)
train_generator = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=32, shuffle=True, augmentor=random_pixels_5, augment_fraction=0.2, num_classes=10, overwrite=False, soft_label=True)
test_generator = AugmentedCIFAR10Generator(X_test, Y_test, batch_size=32, augmentor=None, shuffle=False)

# %%
k = 10
i = Input(shape=X_train[0].shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.25)(x)

#hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)

#last hidden layer i.e.. output layer
x = Dense(k, activation='softmax')(x)

model = Model(i, x)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(
 train_generator, validation_data = test_generator, epochs=6)
# Out:
# Epoch 1/6
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 8ms/step - accuracy: 0.4582 - loss: 1.7016 - val_accuracy: 0.6818 - val_loss: 0.9104
# Epoch 2/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.6868 - loss: 0.8962 - val_accuracy: 0.7124 - val_loss: 0.8460
# Epoch 3/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.7609 - loss: 0.6807 - val_accuracy: 0.7031 - val_loss: 0.8524
# Epoch 4/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8066 - loss: 0.5622 - val_accuracy: 0.7750 - val_loss: 0.6692
# Epoch 5/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.7776 - loss: 1.2604 - val_accuracy: 0.3859 - val_loss: 1.6809
# Epoch 6/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5514 - loss: 35.4044 - val_accuracy: 0.4791 - val_loss: 2.4712

# %%
y_pred = model.predict(test_generator, steps=len(test_generator), verbose = 1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_generator.y_combined, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
print(classification_report(y_pred_classes, y_true))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.64      0.47       585
#            1       0.77      0.70      0.73      1093
#            2       0.66      0.25      0.36      2647
#            3       0.28      0.29      0.28       969
#            4       0.10      0.66      0.17       143
#            5       0.35      0.43      0.38       816
#            6       0.47      0.75      0.58       636
#            7       0.36      0.77      0.49       467
#            8       0.83      0.46      0.59      1806
#            9       0.60      0.72      0.66       838
#
#     accuracy                           0.48     10000
#    macro avg       0.48      0.57      0.47     10000
# weighted avg       0.58      0.48      0.49     10000

# %%
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
print(f"Final Training Accuracy: {r.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {r.history['val_accuracy'][-1]:.4f}")
plt.plot(r.history['accuracy'], label='Train Accuracy', color = '#4ea2d3')
plt.plot(r.history['val_accuracy'], label='Validation Accuracy', color = '#ce1ddd')
plt.title("Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
epochs = len(r.history['accuracy'])
plt.xticks(ticks=range(epochs))
plt.grid(True)
plt.show()
# Out:
# Final Training Accuracy: 0.5017
# Final Validation Accuracy: 0.4791

# %% [markdown]
# ## CNN : max pixel size 5%
# with soft labels 0.9999

# %%
random_pixels_5 = RandomPixelCutout(max_cutout_size=0.05, color=False)
train_generator = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=32, shuffle=True, augmentor=random_pixels_5, augment_fraction=0.2, num_classes=10, overwrite=False, soft_label=True)
test_generator = AugmentedCIFAR10Generator(X_test, Y_test, batch_size=32, augmentor=None, shuffle=False)

# %%
k = 10
i = Input(shape=X_train[0].shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.25)(x)

#hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)

#last hidden layer i.e.. output layer
x = Dense(k, activation='softmax')(x)

model = Model(i, x)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(
 train_generator, validation_data = test_generator, epochs=6)
# Out:
# Epoch 1/6
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 11ms/step - accuracy: 0.4515 - loss: 1.7036 - val_accuracy: 0.6782 - val_loss: 0.9282
# Epoch 2/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.6965 - loss: 0.8692 - val_accuracy: 0.7253 - val_loss: 0.8107
# Epoch 3/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - accuracy: 0.7585 - loss: 0.6990 - val_accuracy: 0.7557 - val_loss: 0.7467
# Epoch 4/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8039 - loss: 0.5757 - val_accuracy: 0.7755 - val_loss: 0.6939
# Epoch 5/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.8394 - loss: 0.4713 - val_accuracy: 0.8120 - val_loss: 0.5798
# Epoch 6/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8653 - loss: 0.3939 - val_accuracy: 0.8087 - val_loss: 0.6196

# %%
y_pred = model.predict(test_generator, steps=len(test_generator), verbose = 1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_generator.y_combined, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
print(classification_report(y_pred_classes, y_true))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       932
#            1       0.93      0.90      0.91      1034
#            2       0.69      0.76      0.73       912
#            3       0.55      0.73      0.63       761
#            4       0.86      0.70      0.77      1235
#            5       0.73      0.73      0.73       994
#            6       0.92      0.79      0.85      1167
#            7       0.79      0.90      0.85       879
#            8       0.92      0.86      0.89      1074
#            9       0.89      0.88      0.88      1012
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000

# %%
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
print(f"Final Training Accuracy: {r.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {r.history['val_accuracy'][-1]:.4f}")
plt.plot(r.history['accuracy'], label='Train Accuracy', color = '#4ea2d3')
plt.plot(r.history['val_accuracy'], label='Validation Accuracy', color = '#ce1ddd')
plt.title("Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
epochs = len(r.history['accuracy'])
plt.xticks(ticks=range(epochs))
plt.grid(True)
plt.show()
# Out:
# Final Training Accuracy: 0.8609
# Final Validation Accuracy: 0.8087

# %% [markdown]
# ## CNN : max pixel size 5%
# with soft labels 0.999

# %%
random_pixels_5 = RandomPixelCutout(max_cutout_size=0.05, color=False)
train_generator = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=32, shuffle=True, augmentor=random_pixels_5, augment_fraction=0.2, num_classes=10, overwrite=False, soft_label=True, soft_label_fraction=0.999)
test_generator = AugmentedCIFAR10Generator(X_test, Y_test, batch_size=32, augmentor=None, shuffle=False)

# %%
k = 10
i = Input(shape=X_train[0].shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.25)(x)

#hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)

#last hidden layer i.e.. output layer
x = Dense(k, activation='softmax')(x)

model = Model(i, x)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(
 train_generator, validation_data = test_generator, epochs=6)
# Out:
# Epoch 1/6
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 46s 14ms/step - accuracy: 0.4507 - loss: 1.7063 - val_accuracy: 0.5853 - val_loss: 1.1851
# Epoch 2/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.6956 - loss: 0.8700 - val_accuracy: 0.7107 - val_loss: 0.8316
# Epoch 3/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.7644 - loss: 0.6824 - val_accuracy: 0.7160 - val_loss: 0.8625
# Epoch 4/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.8085 - loss: 0.5528 - val_accuracy: 0.7611 - val_loss: 0.7569
# Epoch 5/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.8413 - loss: 0.4610 - val_accuracy: 0.7985 - val_loss: 0.6288
# Epoch 6/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8714 - loss: 0.3793 - val_accuracy: 0.8065 - val_loss: 0.6237

# %%
y_pred = model.predict(test_generator, steps=len(test_generator), verbose = 1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_generator.y_combined, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %%
print(classification_report(y_pred_classes, y_true))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83      1091
#            1       0.89      0.93      0.91       954
#            2       0.79      0.67      0.73      1174
#            3       0.54      0.77      0.63       704
#            4       0.85      0.71      0.77      1199
#            5       0.67      0.81      0.74       829
#            6       0.90      0.80      0.84      1120
#            7       0.82      0.87      0.84       936
#            8       0.89      0.89      0.89       994
#            9       0.87      0.87      0.87       999
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.80     10000
# weighted avg       0.82      0.81      0.81     10000

# %%
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
print(f"Final Training Accuracy: {r.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {r.history['val_accuracy'][-1]:.4f}")
plt.plot(r.history['accuracy'], label='Train Accuracy', color = '#4ea2d3')
plt.plot(r.history['val_accuracy'], label='Validation Accuracy', color = '#ce1ddd')
plt.title("Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
epochs = len(r.history['accuracy'])
plt.xticks(ticks=range(epochs))
plt.grid(True)
plt.show()
# Out:
# Final Training Accuracy: 0.8669
# Final Validation Accuracy: 0.8065

# %% [markdown]
# ## CNN : max pixel size 5%
# with soft labels 0.99

# %%
random_pixels_5 = RandomPixelCutout(max_cutout_size=0.05, color=False)
train_generator = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=32, shuffle=True, augmentor=random_pixels_5, augment_fraction=0.2, num_classes=10, overwrite=False, soft_label=True, soft_label_fraction=0.99)
test_generator = AugmentedCIFAR10Generator(X_test, Y_test, batch_size=32, augmentor=None, shuffle=False)

# %%
k = 10
i = Input(shape=X_train[0].shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.25)(x)

#hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)

#last hidden layer i.e.. output layer
x = Dense(k, activation='softmax')(x)

model = Model(i, x)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(
 train_generator, validation_data = test_generator, epochs=6)
# Out:
# Epoch 1/6
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 8ms/step - accuracy: 0.4451 - loss: 1.7256 - val_accuracy: 0.6065 - val_loss: 1.1553
# Epoch 2/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.6915 - loss: 0.8891 - val_accuracy: 0.6589 - val_loss: 1.0861
# Epoch 3/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.7607 - loss: 0.6869 - val_accuracy: 0.7520 - val_loss: 0.7175
# Epoch 4/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.8073 - loss: 0.5561 - val_accuracy: 0.7903 - val_loss: 0.6276
# Epoch 5/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8399 - loss: 0.4572 - val_accuracy: 0.7986 - val_loss: 0.6300
# Epoch 6/6
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.8736 - loss: 0.3701 - val_accuracy: 0.8172 - val_loss: 0.5616

# %%
y_pred = model.predict(test_generator, steps=len(test_generator), verbose = 1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_generator.y_combined, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
print(classification_report(y_pred_classes, y_true))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83      1069
#            1       0.90      0.91      0.91       995
#            2       0.71      0.78      0.74       907
#            3       0.65      0.65      0.65      1005
#            4       0.83      0.79      0.81      1049
#            5       0.71      0.75      0.73       938
#            6       0.85      0.88      0.86       971
#            7       0.85      0.85      0.85      1010
#            8       0.90      0.89      0.89      1003
#            9       0.91      0.86      0.88      1053
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000

# %%
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
print(f"Final Training Accuracy: {r.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {r.history['val_accuracy'][-1]:.4f}")
plt.plot(r.history['accuracy'], label='Train Accuracy', color = '#4ea2d3')
plt.plot(r.history['val_accuracy'], label='Validation Accuracy', color = '#ce1ddd')
plt.title("Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
epochs = len(r.history['accuracy'])
plt.xticks(ticks=range(epochs))
plt.grid(True)
plt.show()
# Out:
# Final Training Accuracy: 0.8686
# Final Validation Accuracy: 0.8172
