# %%
from tensorflow.keras.applications import ResNet50

from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import torch
from custom_transformers import *
import tensorflow as tf
import matplotlib.pyplot as plt
from augmentation_generator_batch_size import *
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Load data

# %%
cifar10 = tf.keras.datasets.cifar10

(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
print(f"X_train.shape: {X_train.shape} \nY_train.shape: {Y_train.shape} \nX_test.shape: {X_test.shape} \nY_test.shape: {Y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# X_train.shape: (50000, 32, 32, 3)
# Y_train.shape: (50000, 1)
# X_test.shape: (10000, 32, 32, 3)
# Y_test.shape: (10000, 1)

# %% [markdown]
# ## Test Data Generator (with fraction 60% to visualize results)

# %% [markdown]
# Adding new samples

# %%
random_squares_cutout = RandomSquaresCutout(max_number_of_squares=10,max_size_ratio=0.1,color=False)
generator = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=16, shuffle=True, augmentor= random_squares_cutout, augment_fraction=0.2, overwrite=False)

batch_x, batch_y = generator[0]

# %%
print(batch_x.shape)
# Out:
# (16, 224, 224, 3)

# %%
#function to denormalize Restnet preprocessing for visualization purposes
def denormalize_resnet(x):
    x = x.copy()
    x[..., 0] += 103.939  # Blue
    x[..., 1] += 116.779  # Green
    x[..., 2] += 123.68   # Red
    # Zamiana BGR -> RGB
    x = x[..., ::-1]
    x = np.clip(x / 255.0, 0, 1)
    return x

n = len(batch_x)
cols = 4
rows = n//cols + int(n%cols != 0)

fig, axes = plt.subplots(rows, cols, figsize=(18, 12))
if rows == 1 or cols == 1:
    axes = np.expand_dims(axes, axis=0)
for i in range(len(batch_x)):
    row = i // cols
    col = i % cols
    ax = axes[row, col]
    ax.imshow(denormalize_resnet(batch_x[i]))
    ax.set_title(batch_y[i], fontsize=8)
    ax.axis('off')

# %% [markdown]
# ## Restnet Training - Random Squares

# %%
random_squares_cutout = RandomSquaresCutout(max_number_of_squares=10,max_size_ratio=0.1,color=False)
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
predictions = Dense(10, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Create generators
train_gen = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=64,
    augmentor=random_squares_cutout, augment_fraction=0.2, overwrite=False)

test_gen = AugmentedCIFAR10Generator(X_test, Y_test,
    batch_size=64, shuffle=False, augmentor=None)


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',  # Works with both one-hot and soft labels
    metrics=['accuracy']
)

history = model.fit(train_gen, validation_data=test_gen, epochs=5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 214s 210ms/step - accuracy: 0.7264 - loss: 0.8221 - val_accuracy: 0.8763 - val_loss: 0.3500
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 202s 215ms/step - accuracy: 0.8241 - loss: 0.5075 - val_accuracy: 0.8806 - val_loss: 0.3487
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 202s 215ms/step - accuracy: 0.7969 - loss: 0.7136 - val_accuracy: 0.8487 - val_loss: 0.6439
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 202s 215ms/step - accuracy: 0.7774 - loss: 1.4140 - val_accuracy: 0.8478 - val_loss: 1.0912
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 263s 216ms/step - accuracy: 0.7643 - loss: 2.7899 - val_accuracy: 0.7951 - val_loss: 3.7563

# %%
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.title("Accuracy over epochs")
plt.grid(True)
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_gen)
print(f"Accuracy on test set: {test_acc:.2%}")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 29s 183ms/step - accuracy: 0.7913 - loss: 3.7800
# Accuracy on test set: 79.51%

# %%
y_pred = model.predict(test_gen)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(Y_test, axis=1)

#searching for correct and incorrect predictions
correct_indices = np.where(y_pred_classes == y_true)[0]
incorrect_indices = np.where(y_pred_classes != y_true)[0]
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 37s 215ms/step

# %%
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def label_check(image_numbers):
    fig, axes = plt.subplots(1, len(image_numbers), figsize=(15, 5))  # Adjust grid size dynamically

    for i, image_number in enumerate(image_numbers):
        ax = axes[i] if len(image_numbers) > 1 else axes

        image = X_test[image_number]
        ax.imshow(image)
        ax.axis('off')

        #resize and preprocess for ResNet
        image_resized = cv2.resize(image, (224, 224))
        image_preprocessed = preprocess_input(image_resized.astype(np.float32))
        image_input = image_preprocessed.reshape(1, 224, 224, 3)

        predicted_label_index = model.predict(image_input).argmax()
        predicted_label = labels[predicted_label_index]

        actual_label_index = int(Y_test[image_number])
        actual_label = labels[actual_label_index]

        correct = predicted_label_index == actual_label_index
        color = 'green' if correct else 'red'

        ax.set_title(f"Real: {actual_label}\nPred: {predicted_label}", fontsize=10, color=color)

    plt.tight_layout()
    plt.show()
label_check(range(80,100))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# <ipython-input-11-92b9130cc612>:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   actual_label_index = int(Y_test[image_number])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
model.save("resnet_model_random_squares.keras")
model.save("resnet_model_random_squares.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# trying smaller cutout (max size ration 0.1 -> 0.05)

# %%
random_squares_cutout = RandomSquaresCutout(max_number_of_squares=10,max_size_ratio=0.05,color=False)
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
predictions = Dense(10, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Create generators
train_gen = AugmentedCIFAR10Generator(X_train, Y_train, batch_size=32,
    augmentor=random_squares_cutout, augment_fraction=0.2, overwrite=False)

test_gen = AugmentedCIFAR10Generator(X_test, Y_test,
    batch_size=32, shuffle=False, augmentor=None)


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',  # Works with both one-hot and soft labels
    metrics=['accuracy']
)

history = model.fit(train_gen, validation_data=test_gen, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 228s 116ms/step - accuracy: 0.7504 - loss: 0.7410 - val_accuracy: 0.8818 - val_loss: 0.3379
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 252s 113ms/step - accuracy: 0.8426 - loss: 0.4514 - val_accuracy: 0.8900 - val_loss: 0.3220
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 211s 113ms/step - accuracy: 0.8553 - loss: 0.4219 - val_accuracy: 0.8943 - val_loss: 0.3061
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 211s 112ms/step - accuracy: 0.8603 - loss: 0.4039 - val_accuracy: 0.8966 - val_loss: 0.3042
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 210s 112ms/step - accuracy: 0.8608 - loss: 0.4008 - val_accuracy: 0.9001 - val_loss: 0.2961

# %%
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.title("Accuracy over epochs")
plt.grid(True)
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_gen)
print(f"Accuracy on test set: {test_acc:.2%}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 30s 97ms/step - accuracy: 0.9042 - loss: 0.2908
# Accuracy on test set: 90.01%

# %%
model.save("resnet_model_random_squares.keras")
model.save("resnet_model_random_squares.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
